# %%
name="Sakshi"
emailaddress="Talegaon Dabhade"
print("my name is:{name} and my mailing address is:{email}".format(name=name,email=emailaddress));
# Out:
# my name is:Sakshi and my mailing address is:Talegaon Dabhade

# %%
x=input("Enter yout name:")
print("hello {x}".format(x=x))
# Out:
# Enter yout name: Sakshi
# hello Sakshi

# %%
width=float(input("Enter the width of the room: "))
height=float(input("Enter the height of the room: "))
area=width * height
print("The width is {width} and height is {height},""then total area is {area}m".format(width=width,height=height,area=area))
# Out:
# Enter the width of the room:  15
# Enter the height of the room:  12
# The width is 15.0 and height is 12.0,then total area is 180.0m

# %%
sqperacre=43560
length=float(input("Enter the length: "))
width=float(input("Enter the width: "))
area=(length*width)/sqperacre
print("The length is {length},""the width is {width},""and the area is {area}".format(length=length,width=width,area=area))
# Out:
# Enter the length:  50
# Enter the width:  60
# The length is 50.0,the width is 60.0,and the area is 0.06887052341597796

# %%
less=0.10
more=0.25
less=int(input("Enter the number of container:"))
more=int(input("how many container more than 1:"))
refund=less*less+more*more
print("total refund:{}".format(refund))
# Out:
# Enter the number of container: 3
# how many container more than 1: 2
# total refund:13
