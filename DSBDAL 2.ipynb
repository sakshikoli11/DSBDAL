# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("Stud_detail.csv")

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         63.0           76.0           60.0               83     2020.0
# 1         73.0           89.0           80.0               91     2019.0
# 2         80.0           76.0           78.0               75     2018.0
# 3         64.0           92.0           64.0               80     2020.0
# 4         72.0           77.0           75.0               87        NaN
# 5         68.0           77.0           69.0               84        NaN
# 6         62.0           76.0           77.0               75        NaN
# 7         72.0           91.0           76.0               99        NaN
# 8         80.0           76.0           76.0              100        NaN
# 9          NaN           92.0           60.0               94     2019.0
# 10         NaN           76.0           71.0               98     2019.0
# 11         NaN           78.0            NaN               99     2021.0
# ...

# %%
df.isnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0        False          False          False            False      False
# 1        False          False          False            False      False
# 2        False          False          False            False      False
# 3        False          False          False            False      False
# 4        False          False          False            False       True
# 5        False          False          False            False       True
# 6        False          False          False            False       True
# 7        False          False          False            False       True
# 8        False          False          False            False       True
# 9         True          False          False            False      False
# 10        True          False          False            False      False
# 11        True          False           True            False      False
# ...

# %%
series=pd.isnull(df["Math_score"])

# %%
df[series]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 9          NaN           92.0           60.0               94     2019.0
# 10         NaN           76.0           71.0               98     2019.0
# 11         NaN           78.0            NaN               99     2021.0
#
#     Placement_offer
# 9               3.0
# 10              3.0
# 11              3.0

# %%
df.notnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         True           True           True             True       True
# 1         True           True           True             True       True
# 2         True           True           True             True       True
# 3         True           True           True             True       True
# 4         True           True           True             True      False
# 5         True           True           True             True      False
# 6         True           True           True             True      False
# 7         True           True           True             True      False
# 8         True           True           True             True      False
# 9        False           True           True             True       True
# 10       False           True           True             True       True
# 11       False           True          False             True       True
# ...

# %%
series1=pd.notnull(df["Math_score"])

# %%
series1
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# Name: Math_score, dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=pd.read_csv("Stud_per.csv")

# %%
df1
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         63.0           76.0           60.0               83     2020.0
# 1         73.0           89.0           80.0               91     2019.0
# 2         80.0           76.0           78.0               75     2018.0
# 3         64.0           92.0           64.0               80     2020.0
# 4         72.0           77.0           75.0               87        NaN
# 5         68.0           77.0           69.0               84        NaN
# 6         62.0           76.0           77.0               75        NaN
# 7         72.0           91.0           76.0               99        NaN
# 8         80.0           76.0           76.0              100        NaN
# 9          NaN           92.0           60.0               94     2019.0
# 10         NaN           76.0           71.0               98     2019.0
# 11         NaN           78.0            NaN               99     2021.0
# ...

# %%
le = LabelEncoder()

# %%
df1['Gender']=le.fit_transform(df1['Gender'])

# %%
newdf=df1

# %%
df1
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         63.0           76.0           60.0               83     2020.0
# 1         73.0           89.0           80.0               91     2019.0
# 2         80.0           76.0           78.0               75     2018.0
# 3         64.0           92.0           64.0               80     2020.0
# 4         72.0           77.0           75.0               87        NaN
# 5         68.0           77.0           69.0               84        NaN
# 6         62.0           76.0           77.0               75        NaN
# 7         72.0           91.0           76.0               99        NaN
# 8         80.0           76.0           76.0              100        NaN
# 9          NaN           92.0           60.0               94     2019.0
# 10         NaN           76.0           71.0               98     2019.0
# 11         NaN           78.0            NaN               99     2021.0
# ...

# %%
missing_values=["Na","na"]

# %%
a=pd.read_csv("Stud_per.csv",na_values=missing_values)

# %%
a
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         63.0           76.0           60.0               83     2020.0
# 1         73.0           89.0           80.0               91     2019.0
# 2         80.0           76.0           78.0               75     2018.0
# 3         64.0           92.0           64.0               80     2020.0
# 4         72.0           77.0           75.0               87        NaN
# 5         68.0           77.0           69.0               84        NaN
# 6         62.0           76.0           77.0               75        NaN
# 7         72.0           91.0           76.0               99        NaN
# 8         80.0           76.0           76.0              100        NaN
# 9          NaN           92.0           60.0               94     2019.0
# 10         NaN           76.0           71.0               98     2019.0
# 11         NaN           78.0            NaN               99     2021.0
# ...

# %%
a.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0         63.0           76.0           60.0               83     2020.0
# 1         73.0           89.0           80.0               91     2019.0
# 2         80.0           76.0           78.0               75     2018.0
# 3         64.0           92.0           64.0               80     2020.0
# 4         72.0           77.0           75.0               87        0.0
# 5         68.0           77.0           69.0               84        0.0
# 6         62.0           76.0           77.0               75        0.0
# 7         72.0           91.0           76.0               99        0.0
# 8         80.0           76.0           76.0              100        0.0
# 9          0.0           92.0           60.0               94     2019.0
# 10         0.0           76.0           71.0               98     2019.0
# 11         0.0           78.0            0.0               99     2021.0
# ...

# %%
m_v=df1['Math_score'].mean()

# %%
m_v
# Out:
# np.float64(69.08695652173913)

# %%
b=df1['Math_score'].fillna(m_v)

# %%
b
# Out:
# 0     63.000000
# 1     73.000000
# 2     80.000000
# 3     64.000000
# 4     72.000000
# 5     68.000000
# 6     62.000000
# 7     72.000000
# 8     80.000000
# 9     69.086957
# 10    69.086957
# 11    69.086957
# 12    75.000000
# 13    64.000000
# 14    60.000000
# 15    64.000000
# 16    75.000000
# 17    78.000000
# 18    64.000000
# 19    62.000000
# 20    64.000000
# 21    74.000000
# 22    63.000000
# 23    73.000000
# 24    76.000000
# 25    62.000000
# 26    66.000000
# 27    66.000000
# 28    79.000000
# 29    77.000000
# 30    79.000000
# 31    65.000000
# 32    68.000000
# 33    71.000000
# 34    74.000000
# 35    64.000000
# 36    79.000000
# 37    66.000000
# 38    75.000000
# 39    69.000000
# 40    64.000000
# 41    70.000000
# 42    77.000000
# 43    60.000000
# 44    69.000000
# 45    60.000000
# 46    62.000000
# 47    60.000000
# 48    70.000000
# Name: Math_score, dtype: float64

# %%
c=df1.replace(to_replace=np.nan,value=-99)

# %%
c
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0    63.000000           76.0           60.0               83     2020.0
# 1    73.000000           89.0           80.0               91     2019.0
# 2    80.000000           76.0           78.0               75     2018.0
# 3    64.000000           92.0           64.0               80     2020.0
# 4    72.000000           77.0           75.0               87      -99.0
# 5    68.000000           77.0           69.0               84      -99.0
# 6    62.000000           76.0           77.0               75      -99.0
# 7    72.000000           91.0           76.0               99      -99.0
# 8    80.000000           76.0           76.0              100      -99.0
# 9    69.086957           92.0           60.0               94     2019.0
# 10   69.086957           76.0           71.0               98     2019.0
# 11   69.086957           78.0          -99.0               99     2021.0
# ...

# %%
d=df1.dropna()

# %%
d
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0    63.000000           76.0           60.0               83     2020.0
# 1    73.000000           89.0           80.0               91     2019.0
# 2    80.000000           76.0           78.0               75     2018.0
# 9    69.086957           92.0           60.0               94     2019.0
# 10   69.086957           76.0           71.0               98     2019.0
# 15   64.000000           80.0           69.0               77     2020.0
# 16   75.000000           92.0           62.0               88     2019.0
# 17   78.000000           75.0           75.0               84     2020.0
# 22   63.000000           76.0           71.0               94     2020.0
# 27   66.000000           92.0           73.0               82     2018.0
# 28   79.000000           85.0           73.0               78     2021.0
# 29   77.000000           92.0           77.0               88     2020.0
# ...

# %%
e=df1.dropna(how='all')

# %%
e
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0    63.000000           76.0           60.0               83     2020.0
# 1    73.000000           89.0           80.0               91     2019.0
# 2    80.000000           76.0           78.0               75     2018.0
# 3    64.000000           92.0           64.0               80     2020.0
# 4    72.000000           77.0           75.0               87        NaN
# 5    68.000000           77.0           69.0               84        NaN
# 6    62.000000           76.0           77.0               75        NaN
# 7    72.000000           91.0           76.0               99        NaN
# 8    80.000000           76.0           76.0              100        NaN
# 9    69.086957           92.0           60.0               94     2019.0
# 10   69.086957           76.0           71.0               98     2019.0
# 11   69.086957           78.0            NaN               99     2021.0
# ...

# %%
f=df1.dropna(axis=1)

# %%
f
# Out:
#     Math_score  Placement_score  Gender  Region
# 0    63.000000               83       0    Pune
# 1    73.000000               91       0  Nashik
# 2    80.000000               75       1    Beed
# 3    64.000000               80       0   Daund
# 4    72.000000               87       1  Mumbai
# 5    68.000000               84       0   Delhi
# 6    62.000000               75       0   Patna
# 7    72.000000               99       1    Pune
# 8    80.000000              100       0  Nashik
# 9    69.086957               94       1    Beed
# 10   69.086957               98       0   Daund
# 11   69.086957               99       0  Mumbai
# 12   75.000000               76       1   Delhi
# 13   64.000000               83       0   Patna
# 14   60.000000               77       1    Pune
# 15   64.000000               77       0  Nashik
# 16   75.000000               88       0    Beed
# 17   78.000000               84       1   Daund
# 18   64.000000               92       0  Mumbai
# ...

# %%
g=df1.dropna(axis=0,how='any')

# %%
g
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_join  \
# 0    63.000000           76.0           60.0               83     2020.0
# 1    73.000000           89.0           80.0               91     2019.0
# 2    80.000000           76.0           78.0               75     2018.0
# 9    69.086957           92.0           60.0               94     2019.0
# 10   69.086957           76.0           71.0               98     2019.0
# 15   64.000000           80.0           69.0               77     2020.0
# 16   75.000000           92.0           62.0               88     2019.0
# 17   78.000000           75.0           75.0               84     2020.0
# 22   63.000000           76.0           71.0               94     2020.0
# 27   66.000000           92.0           73.0               82     2018.0
# 28   79.000000           85.0           73.0               78     2021.0
# 29   77.000000           92.0           77.0               88     2020.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
col=['Math_score','Reading_score','Writing_score','Placement_score']

# %%
df.boxplot(col)
